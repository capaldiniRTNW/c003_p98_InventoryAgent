# %% [markdown]
# ## 1.1 Collect Products

# %% [markdown]
# We begin by collecting the necessary product text data from [DigiKey](https://www.digikey.com/) website.
#
# Run the following notebook to generate a product list with their respective url's and categories.

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import json

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "Connection": "keep-alive",
    "Referer": "https://www.digikey.com/",
}

BASE_URL = "https://www.digikey.com"

def clean_category_name(text):
    cleaned = re.sub(r'\s*[\d,]+\s+?.*$', '', text, flags=re.IGNORECASE)
    return cleaned.strip()

def determine_main_category(name):
    name_lower = name.lower()
    if any(term in name_lower for term in ['anti-static', 'esd', 'clean room']):
        return 'Anti-Static, ESD, Clean Room Products'
    elif any(term in name_lower for term in ['audio', 'microphone', 'speaker', 'amplifier']):
        return 'Audio Products'
    elif any(term in name_lower for term in ['battery', 'batteries']):
        return 'Battery Products'
    elif any(term in name_lower for term in ['cable', 'wire', 'connector']):
        return 'Cables & Connectors'
    elif any(term in name_lower for term in ['capacitor']):
        return 'Capacitors'
    else:
        return 'Other'

def parse_category(text):
    pattern = re.compile(r'^(.*?)([\d,]+)\s*Items$', re.IGNORECASE)
    match = pattern.match(text)
    if match:
        name = match.group(1).strip()
        count_str = match.group(2).replace(',', '')
        count = int(count_str)
        return name, count
    else:
        return text.strip(), 0

def scrape_main_categories():
    try:
        url = "https://www.digikey.com/en/products"
        print(f"Scraping main categories from: {url}")
        response = requests.get(url, headers=HEADERS)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        categories = []

        for link in soup.find_all('a', href=True):
            href = link.get('href', '')
            text = link.get_text(" ",strip=True)
            if '/en/products/' in href and text:
                name, item_count = parse_category(text)
                print(f"Parsed name: '{name}', item count: {item_count}")
                match = re.search(r'([\d,]+)\s*Items?', text, flags=re.IGNORECASE)
                item_count = int(match.group(1).replace(',', '')) if match else 0
                name = clean_category_name(text)
                if name and len(name) > 3:
                    categories.append({
                        'name': name,
                        'url': BASE_URL + href if not href.startswith('http') else href,
                        'category': determine_main_category(name),
                        'items': item_count 
                    })
        
        # Remove duplicates
        seen = set()
        unique_categories = []
        for cat in categories:
            if cat['url'] not in seen:
                seen.add(cat['url'])
                unique_categories.append(cat)
        
        print(f"Found {len(unique_categories)} unique categories")
        return unique_categories
    except Exception as e:
        print(f"Error: {e}")
        return []

# %% [markdown]
# ### Save Raw Data

# %%
categories = scrape_main_categories()

with open('./intermediate_data/Products_List_Raw.json', 'w') as f:
    json.dump(categories, f, indent=2)
# Out:
# Scraping main categories from: https://www.digikey.com/en/products
# Parsed name: 'Automation & Control', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Controllers - Accessories', item count: 0
# Parsed name: 'Controllers - PLC Modules', item count: 0
# Parsed name: 'Controllers - Process, Temperature', item count: 0
# Parsed name: 'Controllers - Programmable Logic (PLC)', item count: 0
# Parsed name: 'Human Machine Interface (HMI)', item count: 0
# Parsed name: 'Industrial Equipment', item count: 0
# Parsed name: 'Machine Vision - Cameras/Sensors', item count: 0
# Parsed name: 'Monitor - Current/Voltage Transducer', item count: 0
# Parsed name: 'Panel Meters', item count: 0
# Parsed name: 'Panel Meters - Counters, Hour Meters', item count: 0
# Parsed name: 'Pneumatics, Hydraulics', item count: 0
# Parsed name: 'Time Delay Relays', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'PLC Modules', item count: 0
# Parsed name: 'Cables, Wires', item count: 0
# Parsed name: 'Cable Assemblies', item count: 0
# Parsed name: 'Barrel - Power Cables', item count: 0
# Parsed name: 'Between Series Adapter Cables', item count: 0
# Parsed name: 'Circular Cable Assemblies', item count: 0
# Parsed name: 'Coaxial Cables (RF)', item count: 0
# Parsed name: 'D-Shaped, Centronics Cables', item count: 0
# Parsed name: 'D-Sub Cables', item count: 0
# Parsed name: 'Flat Flex Cables (FFC, FPC)', item count: 0
# Parsed name: 'Flat Flex, Ribbon Jumper Cables', item count: 0
# Parsed name: 'Jumper Wires, Pre-Crimped Leads', item count: 0
# Parsed name: 'Modular Cables', item count: 0
# Parsed name: 'Pluggable Cables', item count: 0
# Parsed name: 'Power, Line Cables and Extension Cords', item count: 0
# Parsed name: 'Rectangular Cable Assemblies', item count: 0
# Parsed name: 'USB Cables', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Cables, Wires - Management', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Bushings, Grommets', item count: 0
# Parsed name: 'Cable and Cord Grips', item count: 0
# Parsed name: 'Cable Supports and Fasteners', item count: 0
# Parsed name: 'Cable Ties - Holders and Mountings', item count: 0
# Parsed name: 'Cable Ties and Cable Lacing', item count: 0
# Parsed name: 'Grounding Braid, Straps', item count: 0
# Parsed name: 'Heat Shrink Boots, Caps', item count: 0
# Parsed name: 'Heat Shrink Tubing', item count: 0
# Parsed name: 'Labels, Labeling', item count: 0
# Parsed name: 'Protective Hoses, Solid Tubing, Sleeving', item count: 0
# Parsed name: 'Solder Sleeve', item count: 0
# Parsed name: 'Spiral Wrap, Expandable Sleeving', item count: 0
# Parsed name: 'Wire Ducts, Raceways', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Coaxial Cables (RF)', item count: 0
# Parsed name: 'Fiber Optic Cables', item count: 0
# Parsed name: 'Flat Flex Cables (FFC, FPC)', item count: 0
# Parsed name: 'Flat Ribbon Cables', item count: 0
# Parsed name: 'Modular - Flat Cable', item count: 0
# Parsed name: 'Multiple Conductor Cables', item count: 0
# Parsed name: 'Single Conductor Cables (Hook-Up Wire)', item count: 0
# Parsed name: 'Wire Wrap', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Multiple Conductor Cables', item count: 0
# Parsed name: 'Circuit Protection', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Circuit Breakers', item count: 0
# Parsed name: 'Electrical, Specialty Fuses', item count: 0
# Parsed name: 'Fuseholders', item count: 0
# Parsed name: 'Fuses', item count: 0
# Parsed name: 'Gas Discharge Tube Arresters (GDT)', item count: 0
# Parsed name: 'Inrush Current Limiters (ICL)', item count: 0
# Parsed name: 'PTC Resettable Fuses', item count: 0
# Parsed name: 'Surge Suppression ICs', item count: 0
# Parsed name: 'Thermal Cutoffs (Thermal Fuses)', item count: 0
# Parsed name: 'TVS - Diodes', item count: 0
# Parsed name: 'TVS - Mixed Technology', item count: 0
# Parsed name: 'TVS - Thyristors', item count: 0
# Parsed name: 'TVS - Varistors, MOVs', item count: 0
# Parsed name: 'Circuit Protection', item count: 0
# Parsed name: 'Connectors', item count: 0
# Parsed name: 'Backplane Connectors', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'ARINC Inserts', item count: 0
# Parsed name: 'ARINC', item count: 0
# Parsed name: 'Contacts', item count: 0
# Parsed name: 'DIN 41612', item count: 0
# Parsed name: 'Hard Metric, Standard', item count: 0
# Parsed name: 'Housings', item count: 0
# Parsed name: 'Specialized', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Barrel Connectors', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Adapters', item count: 0
# Parsed name: 'Audio Connectors', item count: 0
# Parsed name: 'Power Connectors', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Circular Connectors', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Adapters', item count: 0
# Parsed name: 'Backshells and Cable Clamps', item count: 0
# Parsed name: 'Circular Connectors', item count: 0
# Parsed name: 'Contacts', item count: 0
# Parsed name: 'Housings', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Coaxial Connectors (RF)', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Adapters', item count: 0
# Parsed name: 'Connectors', item count: 0
# Parsed name: 'Contacts', item count: 0
# Parsed name: 'Terminators', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'D-Sub, D-Shaped Connectors', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Accessories - Jackscrews', item count: 0
# Parsed name: 'Adapters', item count: 0
# Parsed name: 'Backshells, Hoods', item count: 0
# Parsed name: 'Contacts', item count: 0
# Parsed name: 'D-Sub Connectors', item count: 0
# Parsed name: 'Housings', item count: 0
# Parsed name: 'Terminators', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'FFC, FPC (Flat Flexible) Connectors', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Contacts', item count: 0
# Parsed name: 'FFC, FPC (Flat Flexible) Connectors', item count: 0
# Parsed name: 'Housings', item count: 0
# Parsed name: 'Modular Connectors', item count: 0
# Parsed name: 'Accesories', item count: 0
# Parsed name: 'Adapters', item count: 0
# Parsed name: 'Inline Module Sockets', item count: 0
# Parsed name: 'Jacks', item count: 0
# Parsed name: 'Jacks With Magnetics', item count: 0
# Parsed name: 'PC Card Sockets', item count: 0
# Parsed name: 'PC Cards - Adapters', item count: 0
# Parsed name: 'Plug Housings', item count: 0
# Parsed name: 'Plugs', item count: 0
# Parsed name: 'Wiring Blocks', item count: 0
# Parsed name: 'Wiring Blocks - Accessories', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Power Entry Connectors', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Inlets, Outlets, Modules', item count: 0
# Parsed name: 'Rectangular Connectors', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Adapters', item count: 0
# Parsed name: 'Arrays, Edge Type, Mezzanine (Board to Board)', item count: 0
# Parsed name: 'Board In, Direct Wire to Board', item count: 0
# Parsed name: 'Board Spacers, Stackers (Board to Board)', item count: 0
# Parsed name: 'Contacts', item count: 0
# Parsed name: 'Free Hanging, Panel Mount', item count: 0
# Parsed name: 'Headers, Male Pins', item count: 0
# Parsed name: 'Headers, Receptacles, Female Sockets', item count: 0
# Parsed name: 'Headers, Specialty Pin', item count: 0
# Parsed name: 'Housings', item count: 0
# Parsed name: 'Spring Loaded', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Terminal Blocks', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Adapters', item count: 0
# Parsed name: 'Barrier Blocks', item count: 0
# Parsed name: 'Contacts', item count: 0
# Parsed name: 'Din Rail, Channel', item count: 0
# Parsed name: 'Headers, Plugs and Sockets', item count: 0
# Parsed name: 'Interface Modules', item count: 0
# Parsed name: 'Panel Mount', item count: 0
# Parsed name: 'Power Distribution', item count: 0
# Parsed name: 'Specialized', item count: 0
# Parsed name: 'Wire to Board', item count: 0
# Parsed name: 'Terminals', item count: 0
# Parsed name: 'Barrel, Bullet Connectors', item count: 0
# Parsed name: 'Housing, Boots', item count: 0
# Parsed name: 'PC Pin Receptacles, Socket Connectors', item count: 0
# Parsed name: 'PC Pin, Single Post Connectors', item count: 0
# Parsed name: 'Quick Connects, Quick Disconnect Connectors', item count: 0
# Parsed name: 'Rectangular Connectors', item count: 0
# Parsed name: 'Ring Connectors', item count: 0
# Parsed name: 'Screw Connectors', item count: 0
# Parsed name: 'Spade Connectors', item count: 0
# Parsed name: 'Specialized Connectors', item count: 0
# Parsed name: 'Turret Connectors', item count: 0
# Parsed name: 'Wire Splice Connectors', item count: 0
# Parsed name: 'USB, DVI, HDMI Connectors', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Adapters', item count: 0
# Parsed name: 'Connectors', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Rectangular Connectors - Headers, Male Pins', item count: 0
# Parsed name: 'Electromechanical', item count: 0
# Parsed name: 'Audio Products', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Alarms, Buzzers, and Sirens', item count: 0
# Parsed name: 'Buzzer Elements, Piezo Benders', item count: 0
# Parsed name: 'Microphones', item count: 0
# Parsed name: 'Speakers', item count: 0
# Parsed name: 'Motors, Solenoids, Driver Boards/Modules', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Motor Driver Boards, Modules', item count: 0
# Parsed name: 'Motors - AC, DC', item count: 0
# Parsed name: 'Solenoids, Actuators', item count: 0
# Parsed name: 'Stepper Motors', item count: 0
# Parsed name: 'Relays', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Automotive Relays', item count: 0
# Parsed name: 'Contactors (Electromechanical)', item count: 0
# Parsed name: 'Contactors (Solid State)', item count: 0
# Parsed name: 'High Frequency (RF) Relays', item count: 0
# Parsed name: 'I/O Relay Module Racks', item count: 0
# Parsed name: 'I/O Relay Modules', item count: 0
# Parsed name: 'Power Relays, Over 2 Amps', item count: 0
# Parsed name: 'Reed Relays', item count: 0
# Parsed name: 'Relay Sockets', item count: 0
# Parsed name: 'Signal Relays, Up to 2 Amps', item count: 0
# Parsed name: 'Solid State Relays', item count: 0
# Parsed name: 'Switches', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Accessories - Caps', item count: 0
# Parsed name: 'DIP Switches', item count: 0
# Parsed name: 'Keylock Switches', item count: 0
# Parsed name: 'Magnetic, Reed Switches', item count: 0
# Parsed name: 'Navigation Switches, Joystick', item count: 0
# Parsed name: 'Pushbutton Switches', item count: 0
# Parsed name: 'Rocker Switches', item count: 0
# Parsed name: 'Rotary Switches', item count: 0
# Parsed name: 'Selector Switches', item count: 0
# Parsed name: 'Slide Switches', item count: 0
# Parsed name: 'Snap Action, Limit Switches', item count: 0
# Parsed name: 'Tactile Switches', item count: 0
# Parsed name: 'Toggle Switches', item count: 0
# Parsed name: 'Relays', item count: 0
# Parsed name: 'Enclosures, Hardware, Office', item count: 0
# Parsed name: 'Boxes, Enclosures, Racks', item count: 0
# Parsed name: 'Backplanes', item count: 0
# Parsed name: 'Box Accessories', item count: 0
# Parsed name: 'Box Components', item count: 0
# Parsed name: 'Boxes', item count: 0
# Parsed name: 'Cams', item count: 0
# Parsed name: 'Card Guide Accessories', item count: 0
# Parsed name: 'Card Guides', item count: 0
# Parsed name: 'Card Rack Accessories', item count: 0
# Parsed name: 'Card Racks', item count: 0
# Parsed name: 'Evaluation, Development Board Enclosures', item count: 0
# Parsed name: 'Handles', item count: 0
# Parsed name: 'Patchbay, Jack Panels', item count: 0
# Parsed name: 'Rack Accessories', item count: 0
# Parsed name: 'Rack Components', item count: 0
# Parsed name: 'Racks', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Computer Equipment', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Adapter Cards', item count: 0
# Parsed name: 'Adapters, Converters', item count: 0
# Parsed name: 'Brackets', item count: 0
# Parsed name: 'Cameras, Projectors', item count: 0
# Parsed name: 'Computer Mouse, Trackballs', item count: 0
# Parsed name: 'Keyboards', item count: 0
# Parsed name: 'KVM Switches (Keyboard Video Mouse)', item count: 0
# Parsed name: 'KVM Switches (Keyboard Video Mouse) - Cables', item count: 0
# Parsed name: 'Magnetic Strip, Smart Card Readers', item count: 0
# Parsed name: 'Memory Card Readers', item count: 0
# Parsed name: 'Printers, Label Makers', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Hardware, Fasteners, Accessories', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Board Spacers, Standoffs', item count: 0
# Parsed name: 'Board Supports', item count: 0
# Parsed name: 'Bumpers, Feet, Pads, Grips', item count: 0
# Parsed name: 'Clips, Hangers, Hooks', item count: 0
# Parsed name: 'Component Insulators, Mounts, Spacers', item count: 0
# Parsed name: 'DIN Rail Channel', item count: 0
# Parsed name: 'Hole Plugs', item count: 0
# Parsed name: 'Knobs', item count: 0
# Parsed name: 'Mounting Brackets', item count: 0
# Parsed name: 'Nuts', item count: 0
# Parsed name: 'Rivets', item count: 0
# Parsed name: 'Screws, Bolts', item count: 0
# Parsed name: 'Washers', item count: 0
# Parsed name: 'Washers - Bushing, Shoulder', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Memory Cards, Modules', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Memory - Modules', item count: 0
# Parsed name: 'Memory Cards', item count: 0
# Parsed name: 'Solid State Drives (SSDs)', item count: 0
# Parsed name: 'Specialized', item count: 0
# Parsed name: 'USB Flash Drives', item count: 0
# Parsed name: 'Networking Solutions', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Gateways, Routers', item count: 0
# Parsed name: 'Media Converters', item count: 0
# Parsed name: 'Miscellaneous', item count: 0
# Parsed name: 'Serial Device Servers', item count: 0
# Parsed name: 'Switches, Hubs', item count: 0
# Parsed name: 'Boxes', item count: 0
# Parsed name: 'Fans, Thermal Management', item count: 0
# Parsed name: 'AC Fans', item count: 0
# Parsed name: 'DC Fans', item count: 0
# Parsed name: 'Fans - Accessories', item count: 0
# Parsed name: 'Fans - Accessories - Fan Cords', item count: 0
# Parsed name: 'Fans - Finger Guards, Filters & Sleeves', item count: 0
# Parsed name: 'Thermal - Accessories', item count: 0
# Parsed name: 'Thermal - Adhesives, Epoxies, Greases, Pastes', item count: 0
# Parsed name: 'Thermal - Heat Pipes, Vapor Chambers', item count: 0
# Parsed name: 'Thermal - Heat Sinks', item count: 0
# Parsed name: 'Thermal - Liquid Cooling', item count: 0
# Parsed name: 'Thermal - Pads, Sheets', item count: 0
# Parsed name: 'Thermal - Thermoelectric, Peltier Assemblies', item count: 0
# Parsed name: 'Thermal - Thermoelectric, Peltier Modules', item count: 0
# Parsed name: 'DC Fans', item count: 0
# Parsed name: 'Integrated Circuits (ICs)', item count: 0
# Parsed name: 'Audio Special Purpose', item count: 0
# Parsed name: 'Clock/Timing', item count: 0
# Parsed name: 'Data Acquisition', item count: 0
# Parsed name: 'Embedded', item count: 0
# Parsed name: 'Integrated Circuits (ICs) Kits', item count: 0
# Parsed name: 'Interface', item count: 0
# Parsed name: 'Linear', item count: 0
# Parsed name: 'Logic', item count: 0
# Parsed name: 'Memory', item count: 0
# Parsed name: 'Power Management (PMIC)', item count: 0
# Parsed name: 'Specialized ICs', item count: 0
# Parsed name: 'Embedded', item count: 0
# Parsed name: 'LED/Optoelectronics', item count: 0
# Parsed name: 'Display Modules - LCD, OLED Character and Numeric', item count: 0
# Parsed name: 'Display Modules - LCD, OLED, Graphic', item count: 0
# Parsed name: 'Display Modules - LED Character and Numeric', item count: 0
# Parsed name: 'Fiber Optics - Transceiver Modules', item count: 0
# Parsed name: 'Infrared, UV, Visible Emitters', item count: 0
# Parsed name: 'Laser Diodes, Modules', item count: 0
# Parsed name: 'LED Indication - Discrete', item count: 0
# Parsed name: 'LED Lighting - COBs, Engines, Modules, Strips', item count: 0
# Parsed name: 'LED Lighting - Color', item count: 0
# Parsed name: 'LED Lighting - White', item count: 0
# Parsed name: 'Optics - Light Pipes', item count: 0
# Parsed name: 'Panel Indicators, Pilot Lights', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'LED Lighting - COBs, Engines, Modules, Strips', item count: 0
# Parsed name: 'Passives', item count: 0
# Parsed name: 'Capacitors', item count: 0
# Parsed name: 'Aluminum Electrolytic Capacitors', item count: 0
# Parsed name: 'Aluminum - Polymer Capacitors', item count: 0
# Parsed name: 'Capacitor Networks, Arrays', item count: 0
# Parsed name: 'Ceramic Capacitors', item count: 0
# Parsed name: 'Electric Double Layer Capacitors (EDLC), Supercapacitors', item count: 0
# Parsed name: 'Film Capacitors', item count: 0
# Parsed name: 'Mica and PTFE Capacitors', item count: 0
# Parsed name: 'Silicon Capacitors', item count: 0
# Parsed name: 'Tantalum Capacitors', item count: 0
# Parsed name: 'Tantalum - Polymer Capacitors', item count: 0
# Parsed name: 'Thin Film Capacitors', item count: 0
# Parsed name: 'Trimmers, Variable Capacitors', item count: 0
# Parsed name: 'Crystals', item count: 0
# Parsed name: 'Filters', item count: 0
# Parsed name: 'Inductors, Coils, Chokes', item count: 0
# Parsed name: 'Adjustable Inductors', item count: 0
# Parsed name: 'Arrays, Signal Transformers', item count: 0
# Parsed name: 'Delay Lines', item count: 0
# Parsed name: 'Fixed Inductors', item count: 0
# Parsed name: 'Wireless Charging Coils', item count: 0
# Parsed name: 'Magnetics - Transformer, Inductor Components', item count: 0
# Parsed name: 'Bobbins (Coil Formers), Mounts, Hardware', item count: 0
# Parsed name: 'Ferrite Cores', item count: 0
# Parsed name: 'Magnetic Wire', item count: 0
# Parsed name: 'Oscillators', item count: 0
# Parsed name: 'Oscillators', item count: 0
# Parsed name: 'Pin Configurable/Selectable Oscillators', item count: 0
# Parsed name: 'Programmable Oscillators', item count: 0
# Parsed name: 'Sockets and Insulators', item count: 0
# Parsed name: 'Stand Alone Programmers', item count: 0
# Parsed name: 'VCOs (Voltage Controlled Oscillators)', item count: 0
# Parsed name: 'Potentiometers, Variable Resistors', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Adjustable Power Resistor', item count: 0
# Parsed name: 'Rotary Potentiometers, Rheostats', item count: 0
# Parsed name: 'Scale Dials', item count: 0
# Parsed name: 'Slide Potentiometers', item count: 0
# Parsed name: 'Thumbwheel Potentiometers', item count: 0
# Parsed name: 'Trimmer Potentiometers', item count: 0
# Parsed name: 'Value Display Potentiometers', item count: 0
# Parsed name: 'Resistors', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Chassis Mount Resistors', item count: 0
# Parsed name: 'Chip Resistor - Surface Mount', item count: 0
# Parsed name: 'Resistor Networks, Arrays', item count: 0
# Parsed name: 'Specialized Resistors', item count: 0
# Parsed name: 'Through Hole Resistors', item count: 0
# Parsed name: 'Resonators', item count: 0
# Parsed name: 'Fixed Inductors', item count: 0
# Parsed name: 'Power', item count: 0
# Parsed name: 'Battery Products', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Batteries Non-Rechargeable (Primary)', item count: 0
# Parsed name: 'Batteries Rechargeable (Secondary)', item count: 0
# Parsed name: 'Battery Chargers', item count: 0
# Parsed name: 'Battery Holders, Clips, Contacts', item count: 0
# Parsed name: 'Battery Packs', item count: 0
# Parsed name: 'Cigarette Lighter Assemblies', item count: 0
# Parsed name: 'Power Supplies', item count: 0
# Parsed name: 'AC AC Wall Adapters', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'AC DC Configurable Power Supplies (Factory Assembled)', item count: 0
# Parsed name: 'AC DC Configurable Power Supply Chassis', item count: 0
# Parsed name: 'AC DC Configurable Power Supply Modules', item count: 0
# Parsed name: 'AC DC Converters', item count: 0
# Parsed name: 'AC DC Desktop, Wall Adapters', item count: 0
# Parsed name: 'DC DC Converters', item count: 0
# Parsed name: 'LED Drivers', item count: 0
# Parsed name: 'Power over Ethernet (PoE)', item count: 0
# Parsed name: 'Solar Cells', item count: 0
# Parsed name: 'Transformers', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Audio Transformers', item count: 0
# Parsed name: 'Bobbins (Coil Formers) Mounts, Hardware', item count: 0
# Parsed name: 'Current Sense Transformers', item count: 0
# Parsed name: 'Ferrite Cores', item count: 0
# Parsed name: 'Isolation Transformers and Autotransformers, Step Up, Step Down', item count: 0
# Parsed name: 'Magnetic Wire', item count: 0
# Parsed name: 'Power Transformers', item count: 0
# Parsed name: 'Pulse Transformers', item count: 0
# Parsed name: 'Specialty Transformers', item count: 0
# Parsed name: 'Switching Converter SMPS Transformers', item count: 0
# Parsed name: 'DC DC Converters', item count: 0
# Parsed name: 'RF and Wireless', item count: 0
# Parsed name: 'Balun', item count: 0
# Parsed name: 'RF Amplifiers', item count: 0
# Parsed name: 'RF Antennas', item count: 0
# Parsed name: 'RF Detectors', item count: 0
# Parsed name: 'RF Directional Coupler', item count: 0
# Parsed name: 'RF Evaluation and Development Kits, Boards', item count: 0
# Parsed name: 'RF Mixers', item count: 0
# Parsed name: 'RF Receiver, Transmitter, and Transceiver Finished Units', item count: 0
# Parsed name: 'RF Shields', item count: 0
# Parsed name: 'RF Switches', item count: 0
# Parsed name: 'RF Transceiver ICs', item count: 0
# Parsed name: 'RF Transceiver Modules', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Semiconductors', item count: 0
# Parsed name: 'Development Boards, Kits, Programmers', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Evaluation and Demonstration Boards and Kits', item count: 0
# Parsed name: 'Evaluation Boards - Analog to Digital Converters (ADCs)', item count: 0
# Parsed name: 'Evaluation Boards - Embedded - Complex Logic (FPGA, CPLD)', item count: 0
# Parsed name: 'Evaluation Boards - Embedded - MCU, DSP', item count: 0
# Parsed name: 'Evaluation Boards - Expansion Boards, Daughter Cards', item count: 0
# Parsed name: 'Evaluation Boards - LED Drivers', item count: 0
# Parsed name: 'Evaluation Boards - Op Amps', item count: 0
# Parsed name: 'Evaluation Boards - Sensors', item count: 0
# Parsed name: 'Programmers, Emulators, and Debuggers', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Discrete', item count: 0
# Parsed name: 'Diodes - Bridge Rectifiers', item count: 0
# Parsed name: 'Diodes - Rectifiers - Arrays', item count: 0
# Parsed name: 'Diodes - Rectifiers - Single', item count: 0
# Parsed name: 'Diodes - RF', item count: 0
# Parsed name: 'Diodes - Zener - Single', item count: 0
# Parsed name: 'Thyristors - SCRs', item count: 0
# Parsed name: 'Thyristors - TRIACs', item count: 0
# Parsed name: 'Transistors - Bipolar (BJT) - Arrays', item count: 0
# Parsed name: 'Transistors - Bipolar (BJT) - RF', item count: 0
# Parsed name: 'Transistors - Bipolar (BJT) Single', item count: 0
# Parsed name: 'Transistors - FETs, MOSFETs - Arrays', item count: 0
# Parsed name: 'Transistors - FETs, MOSFETs - Single', item count: 0
# Parsed name: 'Transistors - IGBTs - Single', item count: 0
# Parsed name: 'Transistors - JFETs', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Embedded Computers', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Interface Boards', item count: 0
# Parsed name: 'Single Board Computers (SBCs)', item count: 0
# Parsed name: 'Integrated Circuits (ICs)', item count: 0
# Parsed name: 'Audio Special Purpose', item count: 0
# Parsed name: 'Clock/Timing', item count: 0
# Parsed name: 'Data Acquisition', item count: 0
# Parsed name: 'Embedded', item count: 0
# Parsed name: 'Interface', item count: 0
# Parsed name: 'Linear', item count: 0
# Parsed name: 'Logic', item count: 0
# Parsed name: 'Memory', item count: 0
# Parsed name: 'PMIC', item count: 0
# Parsed name: 'Specialized ICs', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Isolators', item count: 0
# Parsed name: 'Digital Isolators', item count: 0
# Parsed name: 'Isolators - Gate Drivers', item count: 0
# Parsed name: 'Optoisolators - Logic Output', item count: 0
# Parsed name: 'Optoisolators - Transistor, Photovoltaic Output', item count: 0
# Parsed name: 'Optoisolators - Triac, SCR Output', item count: 0
# Parsed name: 'Special Purpose', item count: 0
# Parsed name: 'Linear - Amplifiers - Instrumentation, OP Amps, Buffer Amps', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Current Sensors', item count: 0
# Parsed name: 'Encoders', item count: 0
# Parsed name: 'Humidity, Moisture Sensors', item count: 0
# Parsed name: 'Image Sensors, Camera', item count: 0
# Parsed name: 'Magnetic Sensors - Linear, Compass (ICs)', item count: 0
# Parsed name: 'Motion Sensors - Accelerometers', item count: 0
# Parsed name: 'Optical Sensors - Ambient Light, IR, UV Sensors', item count: 0
# Parsed name: 'Optical Sensors - Photodiodes', item count: 0
# Parsed name: 'Position Sensors - Angle, Linear Position Measuring', item count: 0
# Parsed name: 'Pressure Sensors, Transducers', item count: 0
# Parsed name: 'Temperature Sensors - Analog and Digital Output', item count: 0
# Parsed name: 'Temperature Sensors - NTC Thermistors', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Humidity, Moisture Sensors', item count: 0
# Parsed name: 'Test and Measurement', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Equipment - Multimeters', item count: 0
# Parsed name: 'Equipment - Oscilloscopes', item count: 0
# Parsed name: 'Equipment - Power Supplies (Test, Bench)', item count: 0
# Parsed name: 'Equipment - Specialty', item count: 0
# Parsed name: 'Test Clips - Alligator, Crocodile, Heavy Duty', item count: 0
# Parsed name: 'Test Clips - Grabbers, Hooks', item count: 0
# Parsed name: 'Test Leads - Banana, Meter Interface', item count: 0
# Parsed name: 'Test Leads - BNC Interface', item count: 0
# Parsed name: 'Test Leads - Jumper, Specialty', item count: 0
# Parsed name: 'Test Leads - Oscilloscope Probes', item count: 0
# Parsed name: 'Test Points', item count: 0
# Parsed name: 'Test Probe Tips', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Equipment - Oscilloscopes', item count: 0
# Parsed name: 'Tools', item count: 0
# Parsed name: 'Crimpers - Crimp Heads, Die Sets', item count: 0
# Parsed name: 'Crimpers, Applicators, Presses', item count: 0
# Parsed name: 'Excavators, Hooks, Picks, Probes, Tuning Tools', item count: 0
# Parsed name: 'Insertion, Extraction', item count: 0
# Parsed name: 'Optical Inspection Equipment', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Arms, Mounts, Stands', item count: 0
# Parsed name: 'Cameras', item count: 0
# Parsed name: 'Eyepieces, Lenses', item count: 0
# Parsed name: 'Illumination Sources', item count: 0
# Parsed name: 'Lamps - Magnifying, Task', item count: 0
# Parsed name: 'Loupes, Magnifiers', item count: 0
# Parsed name: 'Microscopes', item count: 0
# Parsed name: 'Video Inspection Systems', item count: 0
# Parsed name: 'Prototyping, Fabrication Products', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Adapter, Breakout Boards', item count: 0
# Parsed name: 'Card Extenders', item count: 0
# Parsed name: 'Coating, Grease, Repair', item count: 0
# Parsed name: 'Drill Bits, End Mills', item count: 0
# Parsed name: 'Etching and Fabrication Equipment', item count: 0
# Parsed name: 'Jumper Wire', item count: 0
# Parsed name: 'PCB Routers, Milling Machines', item count: 0
# Parsed name: 'Prototype Boards Perforated', item count: 0
# Parsed name: 'Prototype Boards Unperforated', item count: 0
# Parsed name: 'Solderless Breadboards', item count: 0
# Parsed name: 'Screw and Nut Drivers', item count: 0
# Parsed name: 'Screw and Nut Drivers - Sets', item count: 0
# Parsed name: 'Soldering, Desoldering, Rework Products', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Desoldering Braid, Wick, Pumps', item count: 0
# Parsed name: 'Dispensers, Dispenser Tips', item count: 0
# Parsed name: 'Flux, Flux Remover', item count: 0
# Parsed name: 'Fume, Smoke Extraction', item count: 0
# Parsed name: 'Holders, Stands', item count: 0
# Parsed name: 'Solder', item count: 0
# Parsed name: 'Solder Sponges, Tip Cleaners', item count: 0
# Parsed name: 'Solder Stencils, Templates', item count: 0
# Parsed name: 'Soldering Irons, Tweezers, Handles', item count: 0
# Parsed name: 'Soldering, Desoldering, Rework Stations', item count: 0
# Parsed name: 'Soldering, Desoldering, Rework Tips, Nozzles', item count: 0
# Parsed name: 'Static Control, ESD, Clean Room Products', item count: 0
# Parsed name: 'Accessories', item count: 0
# Parsed name: 'Clean Room Swabs and Brushes', item count: 0
# Parsed name: 'Clean Room Treatments, Cleaners, Wipes', item count: 0
# Parsed name: 'Ionizer Equipment', item count: 0
# Parsed name: 'Monitors, Testers', item count: 0
# Parsed name: 'Static Control Clothing', item count: 0
# Parsed name: 'Static Control Device Containers', item count: 0
# Parsed name: 'Static Control Grounding Cords, Straps', item count: 0
# Parsed name: 'Static Control Grounding Mats', item count: 0
# Parsed name: 'Static Control Shielding Bags, Materials', item count: 0
# Parsed name: 'Specialized Tools', item count: 0
# Parsed name: 'Tweezers', item count: 0
# Parsed name: 'Wire Cutters', item count: 0
# Parsed name: 'Wire Strippers and Accessories', item count: 0
# Parsed name: 'See All', item count: 0
# Parsed name: 'Tools', item count: 0
# Parsed name: 'Cable Assemblies', item count: 0
# Parsed name: 'Cables, Wires', item count: 0
# Parsed name: 'Cables, Wires - Management', item count: 0
# Parsed name: 'Connectors, Interconnects', item count: 0
# Parsed name: 'Hardware, Fasteners, Accessories', item count: 0
# Parsed name: 'RF/IF and RFID', item count: 0
# Parsed name: 'Tapes, Adhesives, Materials', item count: 0
# Parsed name: 'Tools', item count: 0
# Parsed name: 'Circuit Protection', item count: 0
# Parsed name: 'Discrete Semiconductor Products', item count: 0
# Parsed name: 'Integrated Circuits (ICs)', item count: 0
# Parsed name: 'Isolators', item count: 0
# Parsed name: 'Power Supplies - Board Mount', item count: 0
# Parsed name: 'RF/IF and RFID', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Test and Measurement', item count: 0
# Parsed name: 'Boxes, Enclosures, Racks', item count: 0
# Parsed name: 'Cable Assemblies', item count: 0
# Parsed name: 'Cables, Wires', item count: 0
# Parsed name: 'Cables, Wires - Management', item count: 0
# Parsed name: 'Connectors, Interconnects', item count: 0
# Parsed name: 'Magnetics - Transformer, Inductor Components', item count: 0
# Parsed name: 'Power Line Filter Modules', item count: 0
# Parsed name: 'Power Supplies - Board Mount', item count: 0
# Parsed name: 'Power Supplies - External/Internal (Off-Board)', item count: 0
# Parsed name: 'Circuit Protection', item count: 0
# Parsed name: 'Crystals, Oscillators, Resonators', item count: 0
# Parsed name: 'Development Boards, Kits, Programmers', item count: 0
# Parsed name: 'Discrete Semiconductor Products', item count: 0
# Parsed name: 'Integrated Circuits (ICs)', item count: 0
# Parsed name: 'RF/IF and RFID', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Crystals, Oscillators, Resonators', item count: 0
# Parsed name: 'Development Boards, Kits, Programmers', item count: 0
# Parsed name: 'Discrete Semiconductor Products', item count: 0
# Parsed name: 'Integrated Circuits (ICs)', item count: 0
# Parsed name: 'Maker/DIY, Educational', item count: 0
# Parsed name: 'RF/IF and RFID', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Test and Measurement', item count: 0
# Parsed name: 'Circuit Protection', item count: 0
# Parsed name: 'Development Boards, Kits, Programmers', item count: 0
# Parsed name: 'Discrete Semiconductor Products', item count: 0
# Parsed name: 'Filters', item count: 0
# Parsed name: 'Integrated Circuits (ICs)', item count: 0
# Parsed name: 'Kits', item count: 0
# Parsed name: 'Cable Assemblies', item count: 0
# Parsed name: 'Connectors, Interconnects', item count: 0
# Parsed name: 'Fans, Thermal Management', item count: 0
# Parsed name: 'Optoelectronics', item count: 0
# Parsed name: 'Relays', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Switches', item count: 0
# Parsed name: 'Tools', item count: 0
# Parsed name: 'View All', item count: 0
# Parsed name: 'Circuit Protection', item count: 0
# Parsed name: 'Development Boards, Kits, Programmers', item count: 0
# Parsed name: 'Discrete Semiconductor Products', item count: 0
# Parsed name: 'Integrated Circuits', item count: 0
# Parsed name: 'Isolators', item count: 0
# Parsed name: 'Optoelectronics', item count: 0
# Parsed name: 'RF/IF and RFID', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Cable Assemblies', item count: 0
# Parsed name: 'Cables, Wires', item count: 0
# Parsed name: 'Cables, Wires - Management', item count: 0
# Parsed name: 'Connectors, Interconnects', item count: 0
# Parsed name: 'Labels, Signs, Barriers, Identification', item count: 0
# Parsed name: 'Tools', item count: 0
# Parsed name: 'Circuit Protection', item count: 0
# Parsed name: 'Development Boards, Kits, Programmers', item count: 0
# Parsed name: 'Discrete Semiconductor Products', item count: 0
# Parsed name: 'Integrated Circuits (ICs)', item count: 0
# Parsed name: 'Isolators', item count: 0
# Parsed name: 'Power Supplies - Board Mount', item count: 0
# Parsed name: 'RF/IF and RFID', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Capacitors', item count: 0
# Parsed name: 'Development Boards, Kits, Programmers', item count: 0
# Parsed name: 'Discrete Semiconductor Products', item count: 0
# Parsed name: 'Integrated Circuits (ICs)', item count: 0
# Parsed name: 'Optoelectronics', item count: 0
# Parsed name: 'Power Supplies - Board Mount', item count: 0
# Parsed name: 'RF/IF and RFID', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Crystals, Oscillators, Resonators', item count: 0
# Parsed name: 'Development Boards, Kits, Programmers', item count: 0
# Parsed name: 'Embedded - Microcontrollers', item count: 0
# Parsed name: 'Integrated Circuits (ICs)', item count: 0
# Parsed name: 'Isolators', item count: 0
# Parsed name: 'RF/IF and RFID', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Audio Products', item count: 0
# Parsed name: 'Battery Products', item count: 0
# Parsed name: 'Circuit Protection', item count: 0
# Parsed name: 'Development Boards, Kits, Programmers', item count: 0
# Parsed name: 'Discrete Semiconductor Products', item count: 0
# Parsed name: 'Integrated Circuits (ICs)', item count: 0
# Parsed name: 'RF/IF and RFID', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'View All', item count: 0
# Parsed name: 'Audio Products', item count: 0
# Parsed name: 'Capacitors', item count: 0
# Parsed name: 'Filters', item count: 0
# Parsed name: 'Inductors, Coils, Chokes', item count: 0
# Parsed name: 'Optoelectronics', item count: 0
# Parsed name: 'RF/IF and RFID', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Transformers', item count: 0
# Parsed name: 'Cable Assemblies', item count: 0
# Parsed name: 'Cables, Wires - Management', item count: 0
# Parsed name: 'Connectors, Interconnects', item count: 0
# Parsed name: 'Relays', item count: 0
# Parsed name: 'Resistors', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Switches', item count: 0
# Parsed name: 'Tools', item count: 0
# Parsed name: 'Automation & Control', item count: 0
# Parsed name: 'Anti-Static, ESD, Clean Room Products', item count: 0
# Parsed name: 'Audio Products', item count: 0
# Parsed name: 'Battery Products', item count: 0
# Parsed name: 'Boxes, Enclosures, Racks', item count: 0
# Parsed name: 'Cable Assemblies', item count: 0
# Parsed name: 'Cables, Wires', item count: 0
# Parsed name: 'Cables, Wires - Management', item count: 0
# Parsed name: 'Capacitors', item count: 0
# Parsed name: 'Circuit Protection', item count: 0
# Parsed name: 'Computer Equipment', item count: 0
# Parsed name: 'Connectors, Interconnects', item count: 0
# Parsed name: 'Crystals, Oscillators, Resonators', item count: 0
# Parsed name: 'Development Boards, Kits, Programmers', item count: 0
# Parsed name: 'Discrete Semiconductor Products', item count: 0
# Parsed name: 'Embedded Computers', item count: 0
# Parsed name: 'Fans, Blowers, Thermal Management', item count: 0
# Parsed name: 'Filters', item count: 0
# Parsed name: 'Hardware, Fasteners, Accessories', item count: 0
# Parsed name: 'Inductors, Coils, Chokes', item count: 0
# Parsed name: 'Industrial Automation and Controls', item count: 0
# Parsed name: 'Industrial Supplies', item count: 0
# Parsed name: 'Integrated Circuits (ICs)', item count: 0
# Parsed name: 'Isolators', item count: 0
# Parsed name: 'Kits', item count: 0
# Parsed name: 'Labels, Signs, Barriers, Identification', item count: 0
# Parsed name: 'Line Protection, Distribution, Backups', item count: 0
# Parsed name: 'Magnetics - Transformer, Inductor Components', item count: 0
# Parsed name: 'Maker/DIY, Educational', item count: 0
# Parsed name: 'Memory - Modules, Cards', item count: 0
# Parsed name: 'Motors, Actuators, Solenoids and Drivers', item count: 0
# Parsed name: 'Networking Solutions', item count: 0
# Parsed name: 'Optical Inspection Equipment', item count: 0
# Parsed name: 'Optics', item count: 0
# Parsed name: 'Optoelectronics', item count: 0
# Parsed name: 'Potentiometers, Variable Resistors', item count: 0
# Parsed name: 'Power Supplies - Board Mount', item count: 0
# Parsed name: 'Power Supplies - External/Internal (Off-Board)', item count: 0
# Parsed name: 'Prototyping, Fabrication Products', item count: 0
# Parsed name: 'Relays', item count: 0
# Parsed name: 'Resistors', item count: 0
# Parsed name: 'RF and Wireless', item count: 0
# Parsed name: 'Sensors, Transducers', item count: 0
# Parsed name: 'Soldering, Desoldering, Rework Products', item count: 0
# Parsed name: 'Switches', item count: 0
# Parsed name: 'Tapes, Adhesives, Materials', item count: 0
# Parsed name: 'Test and Measurement', item count: 0
# Parsed name: 'Tools', item count: 0
# Parsed name: 'Transformers', item count: 0
# Parsed name: 'Uncategorized', item count: 0
# Parsed name: 'Anti-Static, ESD, Clean Room Products', item count: 0
# Parsed name: 'Anti-Static, ESD Bags, Materials', item count: 1293
# Parsed name: 'Anti-Static, ESD Clothing', item count: 1041
# Parsed name: 'Anti-Static, ESD Device Containers', item count: 1191
# Parsed name: 'Anti-Static, ESD Grounding Mats', item count: 1151
# Parsed name: 'Anti-Static, ESD Straps, Grounding Cords', item count: 668
# Parsed name: 'Anti-Static, ESD, Clean Room Accessories', item count: 1175
# Parsed name: 'Clean Room Swabs and Brushes', item count: 316
# Parsed name: 'Clean Room Treatments, Cleaners, Wipes', item count: 409
# Parsed name: 'Ionizer Equipment', item count: 223
# Parsed name: 'Modular ESD Desks, Workstations', item count: 333
# Parsed name: 'Monitors, Testers', item count: 361
# Parsed name: 'Audio Products', item count: 0
# Parsed name: 'Accessories', item count: 595
# Parsed name: 'Alarms, Buzzers, and Sirens', item count: 6182
# Parsed name: 'Amplifiers', item count: 74
# Parsed name: 'Buzzer Elements, Piezo Benders', item count: 254
# Parsed name: 'Guitar Parts, Accessories', item count: 1
# Parsed name: 'Microphones', item count: 1457
# Parsed name: 'Speakers', item count: 3017
# Parsed name: 'Battery Products', item count: 0
# Parsed name: 'Batteries Non-Rechargeable (Primary)', item count: 1751
# Parsed name: 'Batteries Rechargeable (Secondary)', item count: 1712
# Parsed name: 'Battery Chargers', item count: 798
# Parsed name: 'Battery Holders, Clips, Contacts', item count: 1877
# Parsed name: 'Battery Packs', item count: 2125
# Parsed name: 'Battery Product Accessories', item count: 613
# Parsed name: 'Cigarette Lighter Assemblies', item count: 93
# Parsed name: 'Boxes, Enclosures, Racks', item count: 0
# Parsed name: 'Backplanes', item count: 131
# Parsed name: 'Box Accessories', item count: 9971
# Parsed name: 'Box Components', item count: 5779
# Parsed name: 'Boxes', item count: 27369
# Parsed name: 'Cams', item count: 66
# Parsed name: 'Card Guide Accessories', item count: 610
# Parsed name: 'Card Guides', item count: 726
# Parsed name: 'Card Rack Accessories', item count: 400
# Parsed name: 'Card Racks', item count: 272
# Parsed name: 'Evaluation, Development Board Enclosures', item count: 783
# Parsed name: 'Handles', item count: 9635
# Parsed name: 'Latches, Locks', item count: 1193
# Parsed name: 'Patchbay, Jack Panel Accessories', item count: 546
# Parsed name: 'Patchbay, Jack Panels', item count: 2362
# Parsed name: 'Rack Accessories', item count: 13542
# Parsed name: 'Rack Components', item count: 6491
# Parsed name: 'Rack Thermal Management', item count: 3922
# Parsed name: 'Racks', item count: 4077
# Parsed name: 'Storage', item count: 738
# Parsed name: 'Storage Accessories', item count: 49
# Parsed name: 'Cable Assemblies', item count: 0
# Parsed name: 'Barrel Connector Cables', item count: 2104
# Parsed name: 'Barrel Audio Cables', item count: 1212
# Parsed name: 'Barrel Power Cables', item count: 892
# Parsed name: 'Between Series Adapter Cables', item count: 5632
# Parsed name: 'Circular Cable Assemblies', item count: 105463
# Parsed name: 'Coaxial Cables (RF)', item count: 544087
# Parsed name: 'D-Shaped, Centronics Cables', item count: 492
# Parsed name: 'D-Sub Cables', item count: 12375
# Parsed name: 'Fiber Optic Cables', item count: 47782
# Parsed name: 'Firewire Cables (IEEE 1394)', item count: 160
# Parsed name: 'Flat Flex Jumpers, Cables (FFC, FPC)', item count: 2074
# Parsed name: 'Flat Flex Ribbon Jumpers, Cables', item count: 25564
# Parsed name: 'Jumper Wires, Pre-Crimped Leads', item count: 23871
# Parsed name: 'LGH Cables', item count: 409
# Parsed name: 'Modular/Ethernet Cables (RJ45, RJ11)', item count: 57098
# Parsed name: 'Pluggable Cables', item count: 19344
# Parsed name: 'Power, Line Cables and Extension Cords', item count: 6291
# Parsed name: 'Rectangular Cable Assemblies', item count: 139726
# Parsed name: 'Smart Cables', item count: 118
# Parsed name: 'Solid State Lighting Cables', item count: 316
# Parsed name: 'Specialized Cable Assemblies', item count: 2930
# Parsed name: 'USB Cables', item count: 6526
# Parsed name: 'Video Cables (DVI, HDMI)', item count: 2860
# Found 678 unique categories
